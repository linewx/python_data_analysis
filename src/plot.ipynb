# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display, HTML,Markdown
# %matplotlib notebook

# %% [markdown]
# # matplotlib 入门

# %%
plt.hist(np.random.randn(100), bins=20, color='k', alpha=0.3)
# Out:
# <img src="data:image/png;base64,..." width="640">
# (array([ 1.,  0.,  3.,  1.,  2.,  4.,  8.,  9., 12., 14., 11.,  8., 10.,
#          4.,  5.,  3.,  3.,  0.,  1.,  1.]),
#  array([-2.72464967, -2.44269197, -2.16073428, -1.87877659, -1.59681889,
#         -1.3148612 , -1.0329035 , -0.75094581, -0.46898811, -0.18703042,
#          0.09492727,  0.37688497,  0.65884266,  0.94080036,  1.22275805,
#          1.50471575,  1.78667344,  2.06863113,  2.35058883,  2.63254652,
#          2.91450422]),
#  <BarContainer object of 20 artists>)
